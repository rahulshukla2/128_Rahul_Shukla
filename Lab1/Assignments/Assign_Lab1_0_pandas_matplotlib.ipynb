# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Data_for_Transformation.csv')
# print(data)
plt.scatter(data['Age'],data['Salary'])
plt.show()

# %%
plt.hist(data['Salary'],bins=6)
plt.show()

# %%
fig_size = plt.figure(figsize=(7, 5))
plt.bar(data["Country"], data["Salary"], color="blue")
plt.xlabel("Salaries")
plt.ylabel("Countries")
plt.title("Bar chart of country vs salary")
plt.show()
